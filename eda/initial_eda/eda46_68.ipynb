# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('dataset.xlsx')
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#            Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0     44477f75e8169d2                    13               negative
# 1     126e9dd13932f68                    17               negative
# 2     a46b4402a0e5696                     8               negative
# 3     f7d619a94f97c45                     5               negative
# 4     d9e41465789c2b5                    15               negative
# ...               ...                   ...                    ...
# 5639  ae66feb9e4dc3a0                     3               positive
# 5640  517c2834024f3ea                    17               negative
# 5641  5c57d6037fe266d                     4               negative
# 5642  c20c44766f28291                    10               negative
# 5643  2697fdccbfeb7f7                    19               positive
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                                  0
# ...

# %%
sub_dataset = data.iloc[:,46:68]
sub_dataset
# Out:
#      Influenza A, rapid test  Alanine transaminase  Aspartate transaminase  \
# 0                        NaN                   NaN                     NaN
# 1                   negative                   NaN                     NaN
# 2                        NaN                   NaN                     NaN
# 3                        NaN                   NaN                     NaN
# 4                        NaN                   NaN                     NaN
# ...                      ...                   ...                     ...
# 5639                     NaN                   NaN                     NaN
# 5640                     NaN                   NaN                     NaN
# 5641                     NaN                   NaN                     NaN
# 5642                     NaN                   NaN                     NaN
# 5643                     NaN              -0.28361                0.108761
#
# ...

# %%
sub_dataset.dtypes
# Out:
# Influenza A, rapid test                       object
# Alanine transaminase                         float64
# Aspartate transaminase                       float64
# Gamma-glutamyltransferase                    float64
# Total Bilirubin                              float64
# Direct Bilirubin                             float64
# Indirect Bilirubin                           float64
# Alkaline phosphatase                         float64
# Ionized calcium                              float64
# Strepto A                                     object
# Magnesium                                    float64
# pCO2 (venous blood gas analysis)             float64
# Hb saturation (venous blood gas analysis)    float64
# Base excess (venous blood gas analysis)      float64
# pO2 (venous blood gas analysis)              float64
# Fio2 (venous blood gas analysis)             float64
# Total CO2 (venous blood gas analysis)        float64
# pH (venous blood gas analysis)               float64
# ...

# %%
# percentage of missing values 
sub_dataset.isnull().mean()*100
# Out:
# Influenza A, rapid test                      85.471297
# Alanine transaminase                         96.013466
# Aspartate transaminase                       95.995748
# Gamma-glutamyltransferase                    97.289157
# Total Bilirubin                              96.775337
# Direct Bilirubin                             96.775337
# Indirect Bilirubin                           96.775337
# Alkaline phosphatase                         97.448618
# Ionized calcium                              99.114103
# Strepto A                                    94.117647
# Magnesium                                    99.291283
# pCO2 (venous blood gas analysis)             97.590361
# Hb saturation (venous blood gas analysis)    97.590361
# Base excess (venous blood gas analysis)      97.590361
# pO2 (venous blood gas analysis)              97.590361
# Fio2 (venous blood gas analysis)             99.982282
# Total CO2 (venous blood gas analysis)        97.590361
# ...

# %%
# Influenza A, rapid test
influenza = sns.countplot(x='Influenza A, rapid test', data = sub_dataset, palette="ch:.25")

# %%
sub_dataset[['Influenza A, rapid test']].value_counts()
# Out:
# Influenza A, rapid test
# negative                   768
# positive                    52
# dtype: int64

# %%
venous = sub_dataset.loc[:,"pCO2 (venous blood gas analysis)":"HCO3 (venous blood gas analysis)"]
sns.set(rc = {'figure.figsize':(15,8)})
sns.kdeplot(data=venous)
# Out:
# C:\Users\yilin\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#Alanine transaminase
alanine = sub_dataset[['Alanine transaminase']]
sns.set(rc = {'figure.figsize':(15,8)})
sns.kdeplot(data=alanine)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#Aspartate transaminase
aspartate = sub_dataset[['Aspartate transaminase']]
sns.set(rc = {'figure.figsize':(15,8)})
sns.kdeplot(data=aspartate)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#Gamma-glutamyltransferase
gamma = sub_dataset.iloc[:,3]
sns.kdeplot(data=gamma)
# Out:
# <AxesSubplot:xlabel='Gamma-glutamyltransferase\xa0', ylabel='Density'>

# %%
#Total Bilirubin
bilirubin = sub_dataset.iloc[:,4]
sns.kdeplot(data=bilirubin)
# Out:
# <AxesSubplot:xlabel='Total Bilirubin', ylabel='Density'>

# %%
#Direct Bilirubin
dbilirubin = sub_dataset.iloc[:,5]
sns.kdeplot(data=dbilirubin)
# Out:
# <AxesSubplot:xlabel='Direct Bilirubin', ylabel='Density'>

# %%
#overall from alanine trans to Ionized calcium
a_to_i = sub_dataset.iloc[:,1:8]
sns.kdeplot(data=a_to_i)

# Alanine transaminase and aspartate transaminase almost same
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ionized = sub_dataset.iloc[:,8]

sns.kdeplot(data=ionized)
# Out:
# <AxesSubplot:xlabel='Ionized calcium\xa0', ylabel='Density'>

# %%
# Strepto A 
streptoa = sns.countplot(x='Strepto A', data = sub_dataset, palette="ch:.25")

# %%
sub_dataset[['Strepto A']].value_counts()
# Out:
# Strepto A
# negative     297
# positive      34
# not_done       1
# dtype: int64

# %%
# Magnesium
mg = sub_dataset.loc[:,'Magnesium']

sns.kdeplot(data=mg)
# Out:
# <AxesSubplot:xlabel='Magnesium', ylabel='Density'>

# %%
#Rods #                                     
#Segmented                                    
#Promyelocytes 

r_to_p = sub_dataset.loc[:,'Rods #':'Promyelocytes']

sns.kdeplot(data=r_to_p)
# Out:
# <AxesSubplot:ylabel='Density'>
